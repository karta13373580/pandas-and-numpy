# %% [markdown]
# # Pandas tutorial for Asia University

# %%
import pandas as pd
import numpy as np

# %%
dat = pd.read_csv('Pokemon_g1.csv', encoding = 'Windows-1252')

# %%
dat.head()
# Out:
#    #                   Name Type 1  Type 2  ...  Defense  Sp. Atk  Sp. Def  Speed
# 0  1              Bulbasaur  Grass  Poison  ...       49       65       65     45
# 1  2                Ivysaur  Grass  Poison  ...       63       80       80     60
# 2  3               Venusaur  Grass  Poison  ...       83      100      100     80
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...      123      122      120     80
# 4  4             Charmander   Fire     NaN  ...       43       60       50     65
#
# [5 rows x 11 columns]

# %% [markdown]
# # Groupby
#
# - [官方文件](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html)

# %%
#dat.groupby('Type 1', as_index=False).agg({"Attack":"mean"})
dat.groupby('Type 1', as_index=False).Attack.mean()
# Out:
#       Type 1      Attack
# 0        Bug   76.428571
# 1     Dragon   94.000000
# 2   Electric   62.000000
# 3      Fairy   57.500000
# 4   Fighting  102.857143
# 5       Fire   88.642857
# 6      Ghost   53.750000
# 7      Grass   72.923077
# 8     Ground   81.875000
# 9        Ice   67.500000
# 10    Normal   70.625000
# 11    Poison   75.769231
# 12   Psychic   79.181818
# 13      Rock   87.500000
# 14     Water   74.193548

# %% [markdown]
# ### 動手試試看
# - 請計算各個屬性(Type 1)在能力總和(Total)上的平均值，以及速度(Speed)的最小值，並依照能力總和平均由大排到小

# %% [markdown]
# ---

# %% [markdown]
# # Merge, Join, and Concatenate
#
# [Merge, join, and concatenate](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)

# %%
dat_extra = pd.read_csv('Pokemon_g1_extra.csv', encoding = 'Windows-1252')

# %%
dat_extra.head()
# Out:
#    #                   Name Generation Legendary
# 0  1              Bulbasaur          1     False
# 1  2                Ivysaur          1     False
# 2  3               Venusaur          1     False
# 3  3  VenusaurMega Venusaur          1     False
# 4  4             Charmander          1     False

# %%
# 根據index 來增加欄位

dat.join(dat_extra[['Generation', 'Legendary']]).head()
# Out:
#    #                   Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2                Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3               Venusaur  Grass  Poison  ...      100     80           1      False
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...      120     80           1      False
# 4  4             Charmander   Fire     NaN  ...       50     65           1      False
#
# [5 rows x 13 columns]

# %%
# 根據兩份資料的特定欄位數值來合併資料，與SQL join 類似

merge_dat = pd.merge(dat, dat_extra, on = 'Name')

merge_dat.head()
# Out:
#    #_x                   Name Type 1  Type 2  ...  Speed  #_y  Generation  Legendary
# 0    1              Bulbasaur  Grass  Poison  ...     45    1           1      False
# 1    2                Ivysaur  Grass  Poison  ...     60    2           1      False
# 2    3               Venusaur  Grass  Poison  ...     80    3           1      False
# 3    3  VenusaurMega Venusaur  Grass  Poison  ...     80    3           1      False
# 4    4             Charmander   Fire     NaN  ...     65    4           1      False
#
# [5 rows x 14 columns]

# %%
# concat 可以指定增加欄位或是資料筆數，但會直接以原本的排序下去合併，不會做欄位的對應
concate_data = [dat[0:5], dat[10:15]]

pd.concat( concate_data, axis = 0)
# Out:
#      #                     Name Type 1  ... Sp. Atk  Sp. Def  Speed
# 0    1                Bulbasaur  Grass  ...      65       65     45
# 1    2                  Ivysaur  Grass  ...      80       80     60
# 2    3                 Venusaur  Grass  ...     100      100     80
# 3    3    VenusaurMega Venusaur  Grass  ...     122      120     80
# 4    4               Charmander   Fire  ...      60       50     65
# 10   8                Wartortle  Water  ...      65       80     58
# 11   9                Blastoise  Water  ...      85      105     78
# 12   9  BlastoiseMega Blastoise  Water  ...     135      115     78
# 13  10                 Caterpie    Bug  ...      20       20     45
# 14  11                  Metapod    Bug  ...      25       25     30
#
# [10 rows x 11 columns]

# %%
# concat 可以指定增加欄位或是資料筆數，但會直接以原本的排序下去合併，不會做欄位的對應
concate_data = [dat['Name'], dat['Speed']]

pd.concat(concate_data, axis = 1).head()
# Out:
#                     Name  Speed
# 0              Bulbasaur     45
# 1                Ivysaur     60
# 2               Venusaur     80
# 3  VenusaurMega Venusaur     80
# 4             Charmander     65

# %% [markdown]
# ### 動手試試看
#
# - 下方已經準備好兩份資料(分別記錄了班上同學的作業分數與期中考分數)，請將此兩份資料合併起來

# %%
class_dat_1 = pd.DataFrame({'ID':['B0971204','B0981142','B0972830','B0996029'],
                            'homework':[90, 85, 76, 88]})
class_dat_2 = pd.DataFrame({'ID':['B0996029','B0972830','B0981142','B1003852'],
                            'midterm':[63, 80, 93, 85]})

# %%
#merge_dat = pd.merge(class_dat_1, class_dat_2, on = 'ID')
#merge_dat.head()

class_dat_1.join(class_dat_2[['ID', 'midterm']]) #??
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-507078e45a3e> in <module>()
#       1
# ----> 2 class_dat_1.join(class_dat_2[['ID', 'midterm']]) #??
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7259         # For SparseDataFrame's benefit
#    7260         return self._join_compat(
# -> 7261             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7262         )
#    7263
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7282                 right_index=True,
#    7283                 suffixes=(lsuffix, rsuffix),
# -> 7284                 sort=sort,
#    7285             )
#    7286         else:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      81         validate=validate,
#      82     )
# ---> 83     return op.get_result()
#      84
#      85
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in get_result(self)
#     646
#     647         llabels, rlabels = _items_overlap_with_suffix(
# --> 648             ldata.items, lsuf, rdata.items, rsuf
#     649         )
#     650
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    2009         raise ValueError(
#    2010             "columns overlap but no suffix specified: "
# -> 2011             "{rename}".format(rename=to_rename)
#    2012         )
#    2013
#
# ValueError: columns overlap but no suffix specified: Index(['ID'], dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# # Apply

# %%
dat.loc[:,'Total':'Speed'].apply(np.mean, axis = 0)
# Out:
# Total      425.445783
# HP          65.885542
# Attack      76.536145
# Defense     70.861446
# Sp. Atk     71.819277
# Sp. Def     69.150602
# Speed       72.289157
# dtype: float64

# %%
def grade(row):
    if (row['Attack']>100)|(row['Sp. Atk']>100):
        return 'awesome'
    elif (row['Attack']>80)&(row['Speed']>80):
        return 'awesome'
    elif (row['Defense']>60)|(row['HP']>60):
        return 'good'
    else:
        return 'soso'

dat_2 = dat.copy()

dat_2['grade'] = dat_2.apply(grade, axis = 1)

dat_2.head()
# Out:
#    #                   Name Type 1  Type 2  ...  Sp. Atk  Sp. Def  Speed    grade
# 0  1              Bulbasaur  Grass  Poison  ...       65       65     45     soso
# 1  2                Ivysaur  Grass  Poison  ...       80       80     60     good
# 2  3               Venusaur  Grass  Poison  ...      100      100     80     good
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...      122      120     80  awesome
# 4  4             Charmander   Fire     NaN  ...       60       50     65     soso
#
# [5 rows x 12 columns]

# %% [markdown]
# ### 動手試試看
# 請計算出各個屬性(Type 1)中有幾隻神奇寶貝速度(Speed)在60以下

# %% [markdown]
# ---

# %% [markdown]
# # Cross_table, pivot_table, and melt

# %%
pd.crosstab(dat_2['Type 1'], dat_2['grade'])

# %%
dat_2.pivot_table(values='Total', index='Type 1', columns='grade', aggfunc=np.mean)

# %%
pivot_dat = dat_2.pivot_table(values='Total', index='Type 1', columns='grade', aggfunc=np.mean)
pivot_dat.reset_index(inplace = True)

pivot_dat.head()

# %%
pivot_dat.melt(id_vars=['Type 1'], value_vars=['awesome','good','soso']).head(20)

# %% [markdown]
# ### 動手試試看
# 下方已幫各位合併了dat_2 與 dat_extra 兩資料，請以傳說與否(Legendary)為row、評分(grade)為column並計算Speed的最大值

# %%
def grade(row):
    if (row['Attack']>100)|(row['Sp. Atk']>100):
        return 'awesome'
    elif (row['Attack']>80)&(row['Speed']>80):
        return 'awesome'
    elif (row['Defense']>60)|(row['HP']>60):
        return 'good'
    else:
        return 'soso'

dat_2 = dat.copy()
dat_2['grade'] = dat_2.apply(grade, axis = 1)

dat_extra = pd.read_csv('Pokemon_g1_extra.csv', encoding = 'Windows-1252')

# %%
dat_merge = pd.merge(dat_2, dat_extra.drop('#', axis = 1), on = 'Name')
dat_merge.head()

# %% [markdown]
# ---

# %% [markdown]
# # Plot

# %% [markdown]
# ### histogram

# %%
dat['Attack'].hist()

# %% [markdown]
# ### barplot

# %%
type_counts = dat['Type 1'].value_counts()

type_counts.plot.bar()

# %% [markdown]
# ### scatter plot

# %%
dat.plot.scatter('Attack','Defense')

# %% [markdown]
# ---

# %% [markdown]
# # 寫出檔案

# %%
dat.to_csv('out_data.csv', index = False)
