# %% [markdown]
# # Pandas tutorial for Asia University

# %%
import pandas as pd
import numpy as np

# %%
dat = pd.read_csv('Pokemon_g1.csv', encoding = 'Windows-1252')

# %%
dat.head()
# Out:
#    #                   Name Type 1  Type 2  ...  Defense  Sp. Atk  Sp. Def  Speed
# 0  1              Bulbasaur  Grass  Poison  ...       49       65       65     45
# 1  2                Ivysaur  Grass  Poison  ...       63       80       80     60
# 2  3               Venusaur  Grass  Poison  ...       83      100      100     80
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...      123      122      120     80
# 4  4             Charmander   Fire     NaN  ...       43       60       50     65
#
# [5 rows x 11 columns]

# %% [markdown]
# # Select

# %%
dat['Name'].head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
dat.Name.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
dat[['Name']].head()
# Out:
#                     Name
# 0              Bulbasaur
# 1                Ivysaur
# 2               Venusaur
# 3  VenusaurMega Venusaur
# 4             Charmander

# %%
dat[['Name', 'Type 1']].head()
# Out:
#                     Name Type 1
# 0              Bulbasaur  Grass
# 1                Ivysaur  Grass
# 2               Venusaur  Grass
# 3  VenusaurMega Venusaur  Grass
# 4             Charmander   Fire

# %%
dat.select_dtypes(include = 'number').head()
# Out:
#    #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0  1    318  45      49       49       65       65     45
# 1  2    405  60      62       63       80       80     60
# 2  3    525  80      82       83      100      100     80
# 3  3    625  80     100      123      122      120     80
# 4  4    309  39      52       43       60       50     65

# %% [markdown]
# ### 動手試試看
#
# 請印出前10筆神奇寶貝的資料，並且只顯示名稱、屬性(Type 1, Type 2)、以及速度

# %%
dat[["Name","Type 1","Type 2","Speed"]].head(10)
# Out:
#                         Name Type 1  Type 2  Speed
# 0                  Bulbasaur  Grass  Poison     45
# 1                    Ivysaur  Grass  Poison     60
# 2                   Venusaur  Grass  Poison     80
# 3      VenusaurMega Venusaur  Grass  Poison     80
# 4                 Charmander   Fire     NaN     65
# 5                 Charmeleon   Fire     NaN     80
# 6                  Charizard   Fire  Flying    100
# 7  CharizardMega Charizard X   Fire  Dragon    100
# 8  CharizardMega Charizard Y   Fire  Flying    100
# 9                   Squirtle  Water     NaN     43

# %% [markdown]
# ---

# %% [markdown]
# # Filter

# %% [markdown]
# ### .loc 與 .iloc

# %%
dat.loc[:,['Name','HP']].head()
# Out:
#                     Name  HP
# 0              Bulbasaur  45
# 1                Ivysaur  60
# 2               Venusaur  80
# 3  VenusaurMega Venusaur  80
# 4             Charmander  39

# %%
dat.loc[0:5,'#':'Speed']
# Out:
#    #                   Name Type 1  Type 2  ...  Defense  Sp. Atk  Sp. Def  Speed
# 0  1              Bulbasaur  Grass  Poison  ...       49       65       65     45
# 1  2                Ivysaur  Grass  Poison  ...       63       80       80     60
# 2  3               Venusaur  Grass  Poison  ...       83      100      100     80
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...      123      122      120     80
# 4  4             Charmander   Fire     NaN  ...       43       60       50     65
# 5  5             Charmeleon   Fire     NaN  ...       58       80       65     80
#
# [6 rows x 11 columns]

# %%
dat.iloc[1:6,0:3]
# Out:
#    #                   Name Type 1
# 1  2                Ivysaur  Grass
# 2  3               Venusaur  Grass
# 3  3  VenusaurMega Venusaur  Grass
# 4  4             Charmander   Fire
# 5  5             Charmeleon   Fire

# %% [markdown]
# ### boolean filter

# %%
dat[dat['Type 1']=='Fire'].head(10)
# Out:
#      #                       Name Type 1  ... Sp. Atk  Sp. Def  Speed
# 4    4                 Charmander   Fire  ...      60       50     65
# 5    5                 Charmeleon   Fire  ...      80       65     80
# 6    6                  Charizard   Fire  ...     109       85    100
# 7    6  CharizardMega Charizard X   Fire  ...     130       85    100
# 8    6  CharizardMega Charizard Y   Fire  ...     159      115    100
# 42  37                     Vulpix   Fire  ...      50       65     65
# 43  38                  Ninetales   Fire  ...      81      100    100
# 63  58                  Growlithe   Fire  ...      70       50     60
# 64  59                   Arcanine   Fire  ...     100       80     95
# 83  77                     Ponyta   Fire  ...      65       65     90
#
# [10 rows x 11 columns]

# %%
dat[(dat['Type 1']=='Fire')&(dat['Total']>500)]
# Out:
#        #                       Name Type 1  ... Sp. Atk  Sp. Def  Speed
# 6      6                  Charizard   Fire  ...     109       85    100
# 7      6  CharizardMega Charizard X   Fire  ...     130       85    100
# 8      6  CharizardMega Charizard Y   Fire  ...     159      115    100
# 43    38                  Ninetales   Fire  ...      81      100    100
# 64    59                   Arcanine   Fire  ...     100       80     95
# 147  136                    Flareon   Fire  ...      95      110     65
# 158  146                    Moltres   Fire  ...     125       85     90
#
# [7 rows x 11 columns]

# %% [markdown]
# ### boolean filter with .loc

# %%
dat.loc[dat['Type 1']=='Poison', 'Name':'Speed'].head()
# Out:
#          Name  Type 1  Type 2  Total  ...  Defense  Sp. Atk  Sp. Def  Speed
# 28      Ekans  Poison     NaN    288  ...       44       40       54     55
# 29      Arbok  Poison     NaN    438  ...       69       65       79     80
# 34  Nidoran?€  Poison     NaN    275  ...       52       40       40     41
# 35   Nidorina  Poison     NaN    365  ...       67       55       55     56
# 36  Nidoqueen  Poison  Ground    505  ...       87       75       85     76
#
# [5 rows x 10 columns]

# %% [markdown]
# ### 動手試試看
#
# 請篩選出第一屬性為草系或蟲系的神奇寶貝

# %%
dat[(dat["Type 1"]=="Poison")|(dat["Type 1"]=="Bug")]
# Out:
#        #                   Name  Type 1  ... Sp. Atk  Sp. Def  Speed
# 13    10               Caterpie     Bug  ...      20       20     45
# 14    11                Metapod     Bug  ...      25       25     30
# 15    12             Butterfree     Bug  ...      90       80     70
# 16    13                 Weedle     Bug  ...      20       20     50
# 17    14                 Kakuna     Bug  ...      25       25     35
# 18    15               Beedrill     Bug  ...      45       80     75
# 19    15  BeedrillMega Beedrill     Bug  ...      15       80    145
# 28    23                  Ekans  Poison  ...      40       54     55
# 29    24                  Arbok  Poison  ...      65       79     80
# 34    29              Nidoran?€  Poison  ...      40       40     41
# 35    30               Nidorina  Poison  ...      55       55     56
# 36    31              Nidoqueen  Poison  ...      75       85     76
# 38    33               Nidorino  Poison  ...      55       55     65
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Define / delect columns

# %%
dat_ = dat.copy()

dat_['haha'] = 1

dat_.head()
# Out:
#    #                   Name Type 1  Type 2  ...  Sp. Atk  Sp. Def  Speed  haha
# 0  1              Bulbasaur  Grass  Poison  ...       65       65     45     1
# 1  2                Ivysaur  Grass  Poison  ...       80       80     60     1
# 2  3               Venusaur  Grass  Poison  ...      100      100     80     1
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...      122      120     80     1
# 4  4             Charmander   Fire     NaN  ...       60       50     65     1
#
# [5 rows x 12 columns]

# %%
dat_['AS_proportion'] = dat_.Attack / dat_.Speed

dat_.head()
# Out:
#    #                   Name Type 1  Type 2  ...  Sp. Def  Speed  haha  AS_proportion
# 0  1              Bulbasaur  Grass  Poison  ...       65     45     1       1.088889
# 1  2                Ivysaur  Grass  Poison  ...       80     60     1       1.033333
# 2  3               Venusaur  Grass  Poison  ...      100     80     1       1.025000
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...      120     80     1       1.250000
# 4  4             Charmander   Fire     NaN  ...       50     65     1       0.800000
#
# [5 rows x 13 columns]

# %%
dat_ = dat_.drop(['AS_proportion', 'haha'], axis = 1)

dat_.head()
# Out:
#    #                   Name Type 1  Type 2  ...  Defense  Sp. Atk  Sp. Def  Speed
# 0  1              Bulbasaur  Grass  Poison  ...       49       65       65     45
# 1  2                Ivysaur  Grass  Poison  ...       63       80       80     60
# 2  3               Venusaur  Grass  Poison  ...       83      100      100     80
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...      123      122      120     80
# 4  4             Charmander   Fire     NaN  ...       43       60       50     65
#
# [5 rows x 11 columns]

# %% [markdown]
# ### 動手試試看
#
# PART I：請計算每一隻神奇寶貝的攻擊是否比防禦高，將數值新增為'A_greater_than_D'欄位，並印出前五筆資料

# %%
dat2=dat.copy()
dat2["A_greater_than_D"]=dat2.Attack>dat2.Defense
dat2.head()
# Out:
#    #                   Name Type 1  ... Sp. Def  Speed  A_greater_than_D
# 0  1              Bulbasaur  Grass  ...      65     45             False
# 1  2                Ivysaur  Grass  ...      80     60             False
# 2  3               Venusaur  Grass  ...     100     80             False
# 3  3  VenusaurMega Venusaur  Grass  ...     120     80             False
# 4  4             Charmander   Fire  ...      50     65              True
#
# [5 rows x 12 columns]

# %% [markdown]
# PART II：請刪除'A_greater_than_D'欄位

# %%
dat2 = dat2.drop(["A_greater_than_D"],axis = 1)
dat2.head()
# Out:
#    #                   Name Type 1  Type 2  ...  Defense  Sp. Atk  Sp. Def  Speed
# 0  1              Bulbasaur  Grass  Poison  ...       49       65       65     45
# 1  2                Ivysaur  Grass  Poison  ...       63       80       80     60
# 2  3               Venusaur  Grass  Poison  ...       83      100      100     80
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...      123      122      120     80
# 4  4             Charmander   Fire     NaN  ...       43       60       50     65
#
# [5 rows x 11 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Stat

# %%
dat.describe()
# Out:
#                 #       Total          HP  ...     Sp. Atk     Sp. Def       Speed
# count  166.000000  166.000000  166.000000  ...  166.000000  166.000000  166.000000
# mean    75.819277  425.445783   65.885542  ...   71.819277   69.150602   72.289157
# std     45.153246  119.001528   28.119962  ...   34.439106   25.447895   30.141899
# min      1.000000   46.000000   10.000000  ...   15.000000   20.000000    1.000000
# 25%     36.250000  325.000000   48.500000  ...   45.000000   50.000000   50.000000
# 50%     76.500000  436.500000   62.000000  ...   65.000000   70.000000   70.000000
# 75%    115.000000  500.000000   80.000000  ...   95.000000   85.000000   92.250000
# max    151.000000  780.000000  250.000000  ...  194.000000  130.000000  150.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# ## 次數、加總、最大值、最小值

# %%
dat['Name'].count()
# Out:
# 166

# %%
dat['Total'].sum()
# Out:
# 70624

# %%
dat['Total'].max()
# Out:
# 780

# %%
dat['Total'].min()
# Out:
# 46

# %%
dat.loc[:,'HP':'Speed'].sum(axis = 1).head()
# Out:
# 0    318
# 1    405
# 2    525
# 3    625
# 4    309
# dtype: int64

# %%
dat['Total'].head()
# Out:
# 0    318
# 1    405
# 2    525
# 3    625
# 4    309
# Name: Total, dtype: int64

# %% [markdown]
# ### 集中趨勢指標：mean, median, mode
# plus quantile

# %%
dat.mean()
# Out:
# #           75.819277
# Total      425.445783
# HP          65.885542
# Attack      76.536145
# Defense     70.861446
# Sp. Atk     71.819277
# Sp. Def     69.150602
# Speed       72.289157
# dtype: float64

# %%
dat['Attack'].median()
# Out:
# 75.0

# %%
dat['Type 1'].mode()
# Out:
# 0    Water
# dtype: object

# %%
dat['Attack'].quantile(0.5)
# Out:
# 75.0

# %% [markdown]
# ### 離散趨勢指標：std, var

# %%
dat.std()
# Out:
# #           45.153246
# Total      119.001528
# HP          28.119962
# Attack      30.838709
# Defense     28.641336
# Sp. Atk     34.439106
# Sp. Def     25.447895
# Speed       30.141899
# dtype: float64

# %%
dat['Defense'].var()
# Out:
# 820.3261409273449

# %% [markdown]
# ### 動手試試看
# 請根據上面學到的篩選資料與統計量用法，計算飛行系神奇寶貝的平均速度值

# %% [markdown]
# ### 類別型資料

# %%
dat['Type 1'].value_counts()
# Out:
# Water       31
# Normal      24
# Fire        14
# Bug         14
# Grass       13
# Poison      13
# Psychic     11
# Rock        10
# Electric     9
# Ground       8
# Fighting     7
# Ghost        4
# Dragon       3
# Fairy        2
# Ice          2
# Name: Type 1, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Sort

# %%
dat.sort_values('Total').head()
# Out:
#        #             Name Type 1  Type 2  ...  Defense  Sp. Atk  Sp. Def  Speed
# 37    32  Nidoran??Poison    NaN     273  ...       40       40       50      1
# 16    13           Weedle    Bug  Poison  ...       30       20       20     50
# 13    10         Caterpie    Bug     NaN  ...       35       20       20     45
# 139  129         Magikarp  Water     NaN  ...       55       15       20     80
# 17    14           Kakuna    Bug  Poison  ...       50       25       25     35
#
# [5 rows x 11 columns]

# %%
dat.sort_values('Name').head()
# Out:
#        #                       Name   Type 1  ... Sp. Atk  Sp. Def  Speed
# 68    63                       Abra  Psychic  ...     105       55     90
# 153  142                 Aerodactyl     Rock  ...      60       75    130
# 154  142  AerodactylMega Aerodactyl     Rock  ...      70       95    150
# 70    65                   Alakazam  Psychic  ...     135       95    120
# 71    65      AlakazamMega Alakazam  Psychic  ...     175       95    150
#
# [5 rows x 11 columns]
